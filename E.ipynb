# %% [markdown]
# Load Data

# %%
df = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("/Volumes/workspace/default/ev_charging_stataion/ev_20251216.csv")
df.write.mode("overwrite").saveAsTable("workspace.default.EV_Raw_Data")

# %% [markdown]
# Show Sample Data

# %%
display(df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Info/ insights of data

# %%
rows = df.count()
cols = len(df.columns)
display(spark.createDataFrame([(rows, cols)], ["rows", "columns"]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rows</th><th>columns</th></tr></thead><tbody><tr><td>3428</td><td>12</td></tr></tbody></table></div>
